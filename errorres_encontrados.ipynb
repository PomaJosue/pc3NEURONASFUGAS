# %%
Se intentó usar respuesta.status, pero lo correcto es respuesta.status_code.
 Incorrecto:
 print(respuesta.status)
 Correcto:
 print(respuesta.status_code)

# %%
Se intentó graficar antes de crear el DataFrame final.
Para evitar ese error, primero se creó df y luego se usó matplotlib.
